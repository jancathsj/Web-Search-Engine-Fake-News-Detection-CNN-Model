# %%
# %%script C:\Users\Jan Catherine\AppData\Local\Programs\Python\Python38\python.exe
# import sys
# print(sys.version)
# Out:
# 3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)]

# %%
import os
os.chdir('Documents/CMSC Notes/2022-2023 1st Sem/CMSC 190/Dataset-fix-01/fix-02')

# %%
import pandas as pd
import numpy as np
from scipy.stats import sem
from scipy import stats
dataset = pd.read_csv('Fake_features.csv')

# %%
dataset.head()
# Out:
#     entropy  domDigitStart  numDigits  numDots  numSemicolon  numAmpersand  \
# 0 -4.431665          False          4        2             0             0
# 1 -4.483421          False          4        3             0             0
# 2 -4.454020          False          4        2             0             0
# 3 -4.576027          False          8        3             0             0
# 4 -4.525467          False          8        2             0             0
#
#    numSlash  numHyphen  numUnderscore  numEqual  ...  urlLength  numParams  \
# 0         5          7              1         0  ...         98          0
# 1         5          1              0         0  ...         63          0
# 2         4         13              0         0  ...        136          0
# 3         6          4              0         0  ...         84          0
# 4         6         11              0         0  ...        120          0
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   entropy        364 non-null    float64
#  1   domDigitStart  364 non-null    bool
#  2   numDigits      364 non-null    int64
#  3   numDots        364 non-null    int64
#  4   numSemicolon   364 non-null    int64
#  5   numAmpersand   364 non-null    int64
#  6   numSlash       364 non-null    int64
#  7   numHyphen      364 non-null    int64
#  8   numUnderscore  364 non-null    int64
#  9   numEqual       364 non-null    int64
#  10  numQuestion    364 non-null    int64
#  11  urlLength      364 non-null    int64
#  12  numParams      364 non-null    int64
#  13  hasHttp        364 non-null    bool
#  14  hasHttps       364 non-null    bool
#  15  ext            364 non-null    object
#  16  num_%20        364 non-null    int64
#  17  num_@          364 non-null    int64
# ...

# %%
X = dataset.drop("Fake", axis=1)
y = dataset["Fake"]

# %%
def moe(C, std, n):
    er = (std/n**.5)*stats.norm.ppf(C+(1-C)/2,0,1)
    return er

# %%
for column in X:
    if X[column].dtypes == "float64" or  X[column].dtypes == "int64":
        mean = np.mean(X[column])
        #sem = np.std(X[column], ddof=1) / np.sqrt(np.size(X[column]))
        std = X[column].std()
        n = len(X[column])
        er=moe(0.9, std, n)
        print(column, mean, er)
# Out:
# entropy -4.43022607686264 0.01760440950049153
# numDigits 7.096153846153846 0.7200607215462612
# numDots 2.0494505494505493 0.07283921346195632
# numSemicolon 0.0 0.0
# numAmpersand 0.027472527472527472 0.02009716428805109
# numSlash 5.173076923076923 0.12654742937248195
# numHyphen 7.648351648351649 0.5341280671968224
# numUnderscore 0.3516483516483517 0.16283820034553367
# numEqual 0.07967032967032966 0.034070208962688156
# numQuestion 0.054945054945054944 0.019672827312427983
# urlLength 96.54945054945055 3.451452816026264
# numParams 0.027472527472527472 0.02009716428805109
# num_%20 0.03571428571428571 0.041604793016890275
# num_@ 0.013736263736263736 0.010048582144025547
# has_ip 0.0 0.0
# registered 2005.1950549450548 0.6591545513217493
