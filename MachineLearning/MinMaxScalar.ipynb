# %%
# %%script C:\Users\Jan Catherine\AppData\Local\Programs\Python\Python38\python.exe
# import sys
# print(sys.version)
# Out:
# 3.8.10 (tags/v3.8.10:3d8993a, May  3 2021, 11:48:03) [MSC v.1928 64 bit (AMD64)]

# %%
import os
os.chdir('../../Data_Collection_03/02_Preprocessing/02_URL')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Test_imputed.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Fake  registered   entropy  domDigitStart  numDigits  numDots  \
# 0           0     0        2006 -4.202820          False        0.0      2.0
# 1           1     0        2009 -4.346263          False        2.0      2.0
# 2           2     0        2009 -4.122574          False        3.0      2.0
# 3           3     0        2006 -4.471012          False        8.0      2.0
# 4           4     0        2011 -4.387262           True        5.0      1.0
#
#    numSemicolon  numAmpersand  numSlash  ...  hasHttp  hasHttps  ext  num_%20  \
# 0           0.0           0.0       3.0  ...     True     False  gov      0.0
# 1           0.0           0.0       4.0  ...     True     False  com      0.0
# 2           0.0           0.0       5.0  ...     True     False  com      0.0
# 3           0.0           0.0       4.0  ...     True     False   it      0.0
# 4           0.0           0.0       5.0  ...    False      True  org      0.0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     850 non-null    int64
#  1   Fake           850 non-null    int64
#  2   registered     850 non-null    int64
#  3   entropy        850 non-null    float64
#  4   domDigitStart  850 non-null    bool
#  5   numDigits      850 non-null    float64
#  6   numDots        850 non-null    float64
#  7   numSemicolon   850 non-null    float64
#  8   numAmpersand   850 non-null    float64
#  9   numSlash       850 non-null    float64
#  10  numHyphen      850 non-null    float64
#  11  numUnderscore  850 non-null    float64
#  12  numEqual       850 non-null    float64
#  13  numQuestion    850 non-null    float64
#  14  urlLength      850 non-null    float64
#  15  numParams      850 non-null    float64
#  16  hasHttp        850 non-null    bool
# ...

# %%
scaler.fit_transform(df[['entropy','numDigits', 'numDots','numSemicolon','numAmpersand','numSlash','numHyphen','numUnderscore','numEqual','numQuestion','urlLength','numParams','num_%20','num_@','registered']])
#scaler.fit_transform(df[df.columns])
# Out:
# array([[0.737892  , 0.        , 0.14285714, ..., 0.        , 0.        ,
#         0.55263158],
#        [0.64280034, 0.04444444, 0.14285714, ..., 0.        , 0.        ,
#         0.63157895],
#        [0.79108845, 0.06666667, 0.14285714, ..., 0.        , 0.        ,
#         0.63157895],
#        ...,
#        [0.46265287, 0.02222222, 0.14285714, ..., 0.        , 0.        ,
#         0.52631579],
#        [0.46265287, 0.02222222, 0.14285714, ..., 0.        , 0.        ,
#         0.52631579],
#        [0.60324458, 0.02222222, 0.14285714, ..., 0.        , 0.        ,
#         0.52631579]])

# %%
norm_array=scaler.fit_transform(df[['entropy','numDigits', 'numDots','numSemicolon','numAmpersand','numSlash','numHyphen','numUnderscore','numEqual','numQuestion','urlLength','numParams','num_%20','num_@','registered']])
#norm_array=scaler.fit_transform(df[df.columns])

# %%
norm_df = pd.DataFrame(norm_array, columns = ['entropy','numDigits', 'numDots','numSemicolon','numAmpersand','numSlash','numHyphen','numUnderscore','numEqual','numQuestion','urlLength','numParams','num_%20','num_@','registered'])
#norm_df = pd.DataFrame(norm_array, columns = df.columns)

# %%
norm_df.head()
# Out:
#     entropy  numDigits   numDots  numSemicolon  numAmpersand  numSlash  \
# 0  0.737892   0.000000  0.142857           0.0           0.0     0.000
# 1  0.642800   0.044444  0.142857           0.0           0.0     0.125
# 2  0.791088   0.066667  0.142857           0.0           0.0     0.250
# 3  0.560102   0.177778  0.142857           0.0           0.0     0.125
# 4  0.615622   0.111111  0.000000           0.0           0.0     0.250
#
#    numHyphen  numUnderscore  numEqual  numQuestion  urlLength  numParams  \
# 0   0.000000            0.0  0.000000          0.0   0.026936        0.0
# 1   0.333333            0.0  0.058824          1.0   0.296296        0.0
# 2   0.074074            0.0  0.000000          0.0   0.053872        0.0
# 3   0.444444            0.0  0.000000          0.0   0.259259        0.0
# 4   0.111111            0.0  0.000000          0.0   0.168350        0.0
#
#    num_%20  num_@  registered
# 0      0.0    0.0    0.552632
# 1      0.0    0.0    0.631579
# ...

# %%
norm_df.to_csv('06_Test_norm.csv')
